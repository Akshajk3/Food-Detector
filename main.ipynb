# %%
from fastai.vision.all import *

# %%
URLs.FLOWERS
# Out:
# 'https://s3.amazonaws.com/fast-ai-imageclas/oxford-102-flowers.tgz'

# %%
foodPath = untar_data(URLs.FOOD)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5686607872' class='' max='5686607260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5686607872/5686607260 16:23&lt;00:00]
#     </div>

# %%
img = PILImage.create('C:/Users/Kanumuri/.fastai/data/food-101/images/apple_pie/1005649.jpg')
img.show()
# Out:
# <AxesSubplot: >
